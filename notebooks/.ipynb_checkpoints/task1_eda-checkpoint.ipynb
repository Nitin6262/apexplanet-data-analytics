# %%
import pandas as pd

df = pd.read_csv("../data/Sample - Superstore.csv", encoding="latin1")

df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# Missing Value Analysis:
# No missing values were found in the dataset. Therefore, no imputation or row removal was required.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
Q1 = df['Sales'].quantile(0.25)
Q3 = df['Sales'].quantile(0.75)

IQR = Q3 - Q1

print("Q1 =", Q1)
print("Q3 =", Q3)
print("IQR =", IQR)
# Out:
# Q1 = 17.28
# Q3 = 209.94
# IQR = 192.66

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print("Lower Bound =", lower_bound)
print("Upper Bound =", upper_bound)
# Out:
# Lower Bound = -271.71000000000004
# Upper Bound = 498.93

# %%
outliers = df[(df['Sales'] < lower_bound) | (df['Sales'] > upper_bound)]

print("Number of Outliers:", len(outliers))
# Out:
# Number of Outliers: 1167

# %%
df = df[(df['Sales'] >= lower_bound) & (df['Sales'] <= upper_bound)]

print("New Shape:", df.shape)
# Out:
# New Shape: (8827, 21)

# %% [markdown]
# Outlier Handling:
# The IQR method was applied to the Sales column. A total of 1167 outlier records were identified and removed. The dataset size was reduced from 9994 rows to 8827 rows.

# %%
df.to_csv("../data/cleaned_superstore.csv", index=False)

print("Cleaned dataset saved successfully!")
# Out:
# Cleaned dataset saved successfully!

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  8827.000000                           8827
# mean   5016.375892  2016-05-02 15:45:12.541067264
# min       1.000000            2014-01-03 00:00:00
# 25%    2508.500000            2015-05-28 00:00:00
# 50%    5028.000000            2016-07-01 00:00:00
# 75%    7517.500000            2017-05-15 00:00:00
# max    9994.000000            2017-12-30 00:00:00
# std    2888.406540                            NaN
#
#                            Ship Date   Postal Code        Sales     Quantity  \
# count                           8827   8827.000000  8827.000000  8827.000000
# mean   2016-05-06 14:57:05.036818688  55373.635663    92.864853     3.608587
# min              2014-01-07 00:00:00   1040.000000     0.444000     1.000000
# 25%              2015-05-31 00:00:00  23320.000000    15.008000     2.000000
# 50%              2016-07-03 00:00:00  59801.000000    40.880000     3.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8827 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         8827 non-null   int64
#  1   Order ID       8827 non-null   object
#  2   Order Date     8827 non-null   datetime64[ns]
#  3   Ship Date      8827 non-null   datetime64[ns]
#  4   Ship Mode      8827 non-null   object
#  5   Customer ID    8827 non-null   object
#  6   Customer Name  8827 non-null   object
#  7   Segment        8827 non-null   object
#  8   Country        8827 non-null   object
#  9   City           8827 non-null   object
#  10  State          8827 non-null   object
#  11  Postal Code    8827 non-null   int64
#  12  Region         8827 non-null   object
#  13  Product ID     8827 non-null   object
#  14  Category       8827 non-null   object
#  15  Sub-Category   8827 non-null   object
#  16  Product Name   8827 non-null   object
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(df['Sales'], bins=20)

plt.title('Sales Distribution')
plt.xlabel('Sales')
plt.ylabel('Frequency')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.boxplot(x=df['Sales'])

plt.title('Box Plot of Sales')
plt.show()

# %%
category_sales = df.groupby('Category')['Sales'].sum()

category_sales.plot(kind='bar')

plt.title('Sales by Category')
plt.xlabel('Category')
plt.ylabel('Total Sales')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))

sns.heatmap(
    df[['Sales','Quantity','Discount','Profit']].corr(),
    annot=True,
    cmap='Blues'
)

plt.title('Correlation Heatmap')
plt.show()

# %%
monthly_sales = df.groupby(df['Order Date'].dt.month)['Sales'].sum()

plt.figure(figsize=(8,5))

monthly_sales.plot(marker='o')

plt.title('Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Total Sales')

plt.grid(True)
plt.show()

# %% [markdown]
# Key Insights from Analysis
#
# 1. No missing values or duplicate records were found in the dataset, indicating good data quality.
#
# 2. The sales distribution is positively skewed, meaning most orders have lower sales values while only a few orders generate very high sales.
#
# 3. Office Supplies generated the highest total sales among all product categories.
#
# 4. Discount and Profit show a moderate negative correlation (-0.46), indicating that higher discounts generally reduce profitability.
#
# 5. Sales increased significantly toward the end of the year, with November and December recording the highest sales volumes.
